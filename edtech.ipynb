# %%
import pandas as pd
import numpy as np
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Load Data

# %%
# classifiers = pd.read_csv('classifiers.csv', sep=';')
subjects = pd.read_csv('data/subjects.csv', sep=';', encoding='windows-1251')

diagnosticresults = pd.read_csv('data/diagnosticresults.csv', sep=';').drop(['Partition'], axis=1)
diagnosticresultdetails = pd.read_csv('data/diagnosticresultdetails.csv', sep=';').drop(['Partition'], axis=1)

egeresults = pd.read_csv('data/egeresults.csv', sep=';').drop(['Partition'], axis=1)
egeresultdetails = pd.read_csv('data/egeresultdetails.csv', sep=';')
for i in range(2, 14):
    egeresultdetails = pd.concat([egeresultdetails, 
                                  pd.read_csv('data/egeresultdetails{}.csv'.format(i), sep=';')])
egeresultdetails = egeresultdetails.drop(['Partition'], axis=1)

medalistresults = pd.read_csv('data/medalistresults.csv', sep=';').drop(['Partition'], axis=1)
medalistsubjects = pd.read_csv('data/medalistsubjects.csv', sep=';').drop(['Partition'], axis=1)

participants = pd.read_csv('data/participants.csv', sep=';').drop(['Partition'], axis=1)

selfdiagnosticresults = pd.read_csv('data/selfdiagnosticresults.csv', sep=';').drop(['Partition'], axis=1)
selfdiagnosticresultdetails = pd.DataFrame()
for i in range(6):
    selfdiagnosticresultdetails = pd.concat([selfdiagnosticresultdetails, 
                                  pd.read_csv('data/selfdiagnosticresultdetails{}.csv'.format(i), sep=';')])
selfdiagnosticresultdetails = selfdiagnosticresultdetails.drop(['Partition'], axis=1)

# %% [markdown]
# # EDA

# %% [markdown]
# ## Columns Description

# %% [markdown]
# ### Diagnostic
# добавить к диагностике процент оценки, как для егэ

# %%
# on ResultID

# %%
diagnosticresults.head()
# Out:
#    ResultId  Source                         ParticipantId  StudentParallel  \
# 0    187000       0  C70E4C52-34C9-4FBE-9B52-4B78AE43C2DA               11
# 1    239604       0  20647873-4AA8-42E3-B7FE-51DE8E0BEAF5               11
# 2    239606       0  4DFEFA69-EB35-44BD-B239-6AA4DE66F866               11
# 3    239611       0  B4816FC2-CAF4-47EE-8AC7-73E32767E771               11
# 4    239636       0  DFCBA91A-0BE5-4EB9-899E-D0166882F392               11
#
#               TestDate  Mark  MaxMark  SubjectId
# 0  2019-11-08 16:52:48  25.0     33.0         75
# 1  2020-03-20 15:04:34  12.0     30.0         77
# 2  2020-03-20 15:06:20  24.0     31.0         86
# 3  2020-03-20 15:16:21  27.0     31.0         86
# 4  2020-03-23 10:01:31  26.0     31.0          9

# %%
diagnosticresultdetails.head()
# Out:
#         Id  ResultId  Source  NumberInKim  Mark  MaxMark  ClassifierId
# 0  3151177    187000       0            1   0.0      2.0          1883
# 1  3151178    187000       0            2   1.0      1.0          2579
# 2  3151179    187000       0            3   1.0      1.0          2894
# 3  3151180    187000       0            4   0.0      1.0          8855
# 4  3151181    187000       0            5   1.0      1.0          8475

# %%
# В details содержатся данные по каждой задаче для конкретного результата
diagnosticresultdetails[diagnosticresultdetails.ResultId == 187000]
# Out:
#          Id  ResultId  Source  NumberInKim  Mark  MaxMark  ClassifierId
# 0   3151177    187000       0            1   0.0      2.0          1883
# 1   3151178    187000       0            2   1.0      1.0          2579
# 2   3151179    187000       0            3   1.0      1.0          2894
# 3   3151180    187000       0            4   0.0      1.0          8855
# 4   3151181    187000       0            5   1.0      1.0          8475
# 5   3151182    187000       0            6   1.0      1.0          9082
# 6   3151183    187000       0            7   4.0      5.0          9242
# 7   3151184    187000       0            8   1.0      1.0          8583
# 8   3151185    187000       0            9   1.0      1.0          8003
# 9   3151186    187000       0           10   1.0      1.0          9108
# 10  3151187    187000       0           11   1.0      1.0          7546
# 11  3151188    187000       0           12   1.0      1.0          7043
# 12  3151189    187000       0           13   1.0      1.0           208
# 13  3151190    187000       0           14   1.0      1.0          9183
# 14  3151191    187000       0           15   1.0      2.0           596
# 15  3151192    187000       0           16   1.0      1.0          8883
# 16  3151193    187000       0           17   1.0      1.0          8405
# 17  3151194    187000       0           18   1.0      1.0          8604
# 18  3151195    187000       0           19   0.0      1.0          9259
# 19  3151196    187000       0           20   0.0      1.0          1883
# 20  3151197    187000       0           21   1.0      1.0          2380
# 21  3151198    187000       0           22   1.0      1.0          5224
# 22  3151199    187000       0           23   1.0      1.0          2380
# 23  3151200    187000       0           24   3.0      4.0          2137

# %% [markdown]
# ### Ege

# %%
egeresults.head()
# Out:
#                                      Id                         ParticipantId  \
# 0  000176B3-FD22-464F-80E4-1903332D8EFF  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
# 1  0007FBF5-CECE-4769-AAA4-F8D3B54460DE  4C5F3B22-6439-4255-83A3-9C2573607F96
# 2  0008DF1B-A868-4A0E-AFEC-3F5F3EDB3D5D  539BF0E1-24D7-4323-8B36-EECAC7B5C0C5
# 3  000CBD0B-5513-4F9D-9E31-1BA125B9472B  1BAE7BE4-5C78-4E0D-B29D-7E06454C830B
# 4  000F3DEE-44BF-40C9-8D0F-DB86C15A16E3  5B3D82FB-D840-44DE-ADC0-A9CBEB2C06B2
#
#      DateExam  MarkPercent  SubjectId
# 0  2020-07-16           75         86
# 1  2020-07-20           77          9
# 2  2020-07-03           25         27
# 3  2020-07-13           83         77
# 4  2020-07-20           91          4

# %%
egeresultdetails.head()
# Out:
#    Id                              ResultId  Part  NumberInPart  Number  Mark  \
# 0  39  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             1       0     1
# 1  40  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             2       0     1
# 2  41  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             3       0     1
# 3  42  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             4       0     1
# 4  43  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             5       0     1
#
#    MaxMark  ClassifierId
# 0        1          3914
# 1        1          1252
# 2        1           498
# 3        1           498
# 4        1           498

# %%
egeresults[egeresults.Id == '4EF9DB0D-2E75-4654-A74C-0000317B2FC1']
# Out:
#                                          Id  \
# 11936  4EF9DB0D-2E75-4654-A74C-0000317B2FC1
#
#                               ParticipantId    DateExam  MarkPercent  \
# 11936  EAEE3A32-10FF-4A48-B5D6-3378D7560EA2  2020-07-06           84
#
#        SubjectId
# 11936         75

# %%
# Аналогично с диагностикой
egeresultdetails[egeresultdetails.ResultId == '4EF9DB0D-2E75-4654-A74C-0000317B2FC1'].sort_values(['Part', 'NumberInPart'])
# Out:
#     Id                              ResultId  Part  NumberInPart  Number  \
# 0   39  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             1       0
# 1   40  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             2       0
# 2   41  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             3       0
# 3   42  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             4       0
# 4   43  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             5       0
# 5   44  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             6       0
# 6   45  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             7       0
# 7   46  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             8       0
# 8   47  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1             9       0
# 9   48  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            10       0
# 10  49  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            11       0
# 11  50  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            12       0
# 12  51  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            13       0
# 13  52  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            14       0
# 14  53  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            15       0
# 15  54  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            16       0
# 16  55  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            17       0
# 17  56  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            18       0
# 18  57  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            19       0
# 19  58  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            20       0
# 20  59  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            21       0
# 21  60  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            22       0
# 22  61  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            23       0
# 23  62  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            24       0
# 24  63  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            25       0
# 25  64  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     1            26       0
# 26  65  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             1       0
# 27  66  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             2       0
# 28  67  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             3       0
# 29  68  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             4       0
# 30  69  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             5       0
# 31  70  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             6       0
# 32  71  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             7       0
# 33  72  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             8       0
# 34  73  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2             9       0
# 35  74  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2            10       0
# 36  75  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2            11       0
# 37  76  4EF9DB0D-2E75-4654-A74C-0000317B2FC1     2            12       0
#
#     Mark  MaxMark  ClassifierId
# 0      1        1          3914
# 1      1        1          1252
# 2      1        1           498
# 3      1        1           498
# 4      1        1           498
# 5      1        1           498
# 6      0        1           498
# 7      5        5           498
# 8      1        1           498
# 9      1        1           498
# 10     0        1           498
# 11     1        1           498
# 12     1        1           498
# 13     1        1           498
# 14     1        1           498
# 15     2        2           498
# 16     1        1           498
# 17     1        1           498
# 18     1        1           498
# 19     0        1           498
# 20     1        1           498
# 21     1        1          3914
# 22     0        1          1252
# 23     1        1          1252
# 24     1        1          1252
# 25     4        4           498
# 26     1        1             0
# 27     4        5             0
# 28     1        1             0
# 29     1        1             0
# 30     1        2             0
# 31     1        2             0
# 32     3        3             0
# 33     3        3             0
# 34     1        2             0
# 35     1        2             0
# 36     1        1             0
# 37     1        1             0

# %% [markdown]
# ### Medalist
# Type = 0 победитель олимпиады по предметам;
# Type = 1 медалист

# %%
print(medalistresults.shape)
medalistresults.head()
# Out:
# (1836, 3)
#    Id  Type                         ParticipantId
# 0  25     0  B693A6E8-E8C9-40F5-8E63-0083317462F5
# 1  27     0  EAC81C2C-E4C8-4213-A077-C013281F477A
# 2  50     0  3E8F291A-8192-4389-B1E2-B1AF873E152F
# 3  71     0  6C9A5162-317C-4A61-9E80-551CA908EEF6
# 4  97     0  B8E650D4-36C1-41F0-B149-F0436437C1C7

# %%
#  SubjectId - Id предмета олимпиады
print(medalistsubjects.shape)
medalistsubjects.head()
# Out:
# (70, 3)
#    ResultId  Id  SubjectId
# 0       379   1         48
# 1       399  24         64
# 2       415  40         58
# 3       436  63         78
# 4       442  69         86

# %% [markdown]
# ### Selfdiagnostic

# %%
selfdiagnosticresults.head()
# Out:
#         Id                         ParticipantId  StudentParallel  \
# 0  2369230  594F27DE-1479-476C-8CB6-A76EA1AB25C9                9
# 1  2370235  C4285D8C-9B23-43C8-AECD-EC4271D48A59               10
# 2  2375593  9B7CD84C-BEB9-492A-B878-49A4750D805B                9
# 3  2375717  9B7CD84C-BEB9-492A-B878-49A4750D805B                9
# 4  2375739  9B7CD84C-BEB9-492A-B878-49A4750D805B                9
#
#               TestDate  Mark  MaxMark  SubjectId
# 0  2019-09-01 00:03:20   0.0     10.0         27
# 1  2019-09-01 10:38:27  14.0     21.0         86
# 2  2019-09-01 17:36:53   8.0     12.0         75
# 3  2019-09-01 17:50:07   3.0     12.0         75
# 4  2019-09-01 17:53:20   7.0     10.0         27

# %%
selfdiagnosticresultdetails.head()
# Out:
#          Id  ResultId  NumberInKim  Mark  MaxMark  ClassifierId
# 0  36837244   2369230            1   0.0      1.0          5206
# 1  36837245   2369230            2   0.0      1.0         10170
# 2  36837246   2369230            3   0.0      1.0          9822
# 3  36837247   2369230            4   0.0      1.0          6507
# 4  36837248   2369230            5   0.0      1.0          3746

# %%
selfdiagnosticresults[selfdiagnosticresults.Id == 2369230]
# Out:
#         Id                         ParticipantId  StudentParallel  \
# 0  2369230  594F27DE-1479-476C-8CB6-A76EA1AB25C9                9
#
#               TestDate  Mark  MaxMark  SubjectId
# 0  2019-09-01 00:03:20   0.0     10.0         27

# %%
selfdiagnosticresultdetails[selfdiagnosticresultdetails.ResultId == 2369230]
# Out:
#          Id  ResultId  NumberInKim  Mark  MaxMark  ClassifierId
# 0  36837244   2369230            1   0.0      1.0          5206
# 1  36837245   2369230            2   0.0      1.0         10170
# 2  36837246   2369230            3   0.0      1.0          9822
# 3  36837247   2369230            4   0.0      1.0          6507
# 4  36837248   2369230            5   0.0      1.0          3746
# 5  36837249   2369230            6   0.0      1.0          6525
# 6  36837250   2369230            7   0.0      1.0          9915
# 7  36837251   2369230            8   0.0      1.0          6525
# 8  36837252   2369230            9   0.0      2.0          4417

# %% [markdown]
# ### Other

# %%
subjects
# Out:
#     Id                                               Name
# 0    1                                Академический класс
# 1    2                              Академический профиль
# 2    3                                            Алгебра
# 3    4                                    Английский язык
# 4    5                           Английский язык (устный)
# ..  ..                                                ...
# 92  93                                        Электроника
# 93  94                                    Кадетский класс
# 94  95  Ознакомительный тренинг для оценки профессиона...
# 95  96  Ознакомительный тренинг для оценки профессиона...
# 96  97  Ознакомительный тренинг для оценки профессиона...
#
# [97 rows x 2 columns]

# %% [markdown]
# # Feature Generation

# %%
# добавить учет оценок по другим предметам +
# добавить фичу динамики оценок за пробники
# добавить количество баллов за разные части
# средние результаты селфдиагностики и диагностики +

# shap графики для оценки фичей
# свои модели для каждого предмета
# KFold

# досопостваить предметы

# %%
participants = participants.rename(columns={'Id': 'ParticipantId'})

# %%
diagnosticresults['MarkPercent'] = round(100 * diagnosticresults.Mark / diagnosticresults.MaxMark)
selfdiagnosticresults['MarkPercent'] = round(100 * selfdiagnosticresults.Mark / selfdiagnosticresults.MaxMark)

# %%
diagnosticresults_mean_mark = pd.DataFrame(diagnosticresults.groupby(['ParticipantId', 'SubjectId']).MarkPercent.mean()).reset_index()
selfdiagnosticresults_mean_mark = pd.DataFrame(selfdiagnosticresults.groupby(['ParticipantId', 'SubjectId']).MarkPercent.mean()).reset_index()

# %%
data = pd.merge(egeresults, participants, on=['ParticipantId'])

# %%
data.head()
# Out:
#                                      Id                         ParticipantId  \
# 0  000176B3-FD22-464F-80E4-1903332D8EFF  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
# 1  16B0AF81-E095-4646-A672-F8B2EFE824BE  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
# 2  E3763A42-0057-4281-92FD-CC6F5C0ED9A4  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
# 3  0007FBF5-CECE-4769-AAA4-F8D3B54460DE  4C5F3B22-6439-4255-83A3-9C2573607F96
# 4  89EDADB6-B6B8-42A4-9E02-2681F3D98B02  4C5F3B22-6439-4255-83A3-9C2573607F96
#
#      DateExam  MarkPercent  SubjectId  Parallel  \
# 0  2020-07-16           75         86        11
# 1  2020-07-06           79         75        11
# 2  2020-07-20           74          9        11
# 3  2020-07-20           77          9        11
# 4  2020-07-07           86         75        11
#
#                                  OOCode
# 0  8D6D2905-A151-4B1B-AB98-F879C00CC736
# 1  8D6D2905-A151-4B1B-AB98-F879C00CC736
# 2  8D6D2905-A151-4B1B-AB98-F879C00CC736
# 3  BFC27424-5AAD-465E-B169-A2474EBEE0C0
# 4  BFC27424-5AAD-465E-B169-A2474EBEE0C0

# %%
subjects_compliance = dict()
for id in subjects[subjects.Id.isin(egeresults.SubjectId.unique())].Id.values:
    subjects_compliance[id] = []
    subjects_compliance[id].append(id)

subjects_compliance[4].append(5)
subjects_compliance[5].append(4)

subjects_compliance[49].append(3)
subjects_compliance[49].append(13)
subjects_compliance[49].append(48)

subjects_compliance[31].append(11)
subjects_compliance[31].append(32)

subjects_compliance[61].append(91)

# %%
diagnosticresults_processed = pd.DataFrame()
for key in subjects_compliance:
    temp = pd.DataFrame(diagnosticresults[diagnosticresults.SubjectId.isin(subjects_compliance[key])] \
                                         .groupby('ParticipantId').MarkPercent.min()).reset_index() \
                                         .rename(columns={'MarkPercent': 'DiagnosticMarkPercentMin'})
    temp['DiagnosticMarkPercentMean'] = pd.DataFrame(diagnosticresults[diagnosticresults.SubjectId.isin(subjects_compliance[key])] \
                                                                      .groupby('ParticipantId').MarkPercent.mean()).reset_index() \
                                                                      .rename(columns={'MarkPercent': 'DiagnosticMarkPercentMean'})['DiagnosticMarkPercentMean']
    temp['DiagnosticMarkPercentMax'] = pd.DataFrame(diagnosticresults[diagnosticresults.SubjectId.isin(subjects_compliance[key])] \
                                                                      .groupby('ParticipantId').MarkPercent.max()).reset_index() \
                                                                      .rename(columns={'MarkPercent': 'DiagnosticMarkPercentMax'})['DiagnosticMarkPercentMax']
    temp['SubjectId'] = key
    diagnosticresults_processed = pd.concat([diagnosticresults_processed,
                                            temp])
    
data = pd.merge(data, diagnosticresults_processed, on=['ParticipantId', 'SubjectId'], how='left')

# %%
diagnosticresults_processed
# Out:
#                            ParticipantId  DiagnosticMarkPercentMin  \
# 0   003CF9B0-9E7C-4414-98B9-32B8CF410766                      52.0
# 1   01D63287-C679-4925-8DE4-AF9961575F9C                      68.0
# 2   048B145D-93FF-43BA-98BD-19917C465A11                      82.0
# 3   06EF63E8-5C61-4082-B9A1-7C02AE98E3C4                      68.0
# 4   07DCAFCA-5F39-4A41-A243-1DEEBC48708C                      68.0
# ..                                   ...                       ...
# 74  F97D31DC-4149-438E-AD5C-88B229217FAF                      55.0
# 75  F9D7DF1B-8AE1-4F91-9AAC-0FB195EF5D49                      68.0
# 76  FBC219FE-0CC3-4EAE-AE60-EA666A76BB1A                      28.0
# 77  FD2EFC97-95AA-4650-8263-32F20E70C770                      39.0
# 78  FDA13430-900C-4FE9-A6E8-0F15C5A53CA7                      94.0
#
#     DiagnosticMarkPercentMean  DiagnosticMarkPercentMax  SubjectId
# 0                        52.0                      52.0          4
# 1                        68.0                      68.0          4
# 2                        82.0                      82.0          4
# 3                        79.5                      91.0          4
# 4                        68.0                      68.0          4
# ..                        ...                       ...        ...
# 74                       61.5                      68.0         86
# 75                       68.0                      68.0         86
# 76                       38.0                      48.0         86
# 77                       52.0                      65.0         86
# 78                       94.0                      94.0         86
#
# [2025 rows x 5 columns]

# %%
selfdiagnosticresults_processed = pd.DataFrame()
for key in subjects_compliance:
    temp = pd.DataFrame(selfdiagnosticresults[selfdiagnosticresults.SubjectId.isin(subjects_compliance[key])] \
                                         .groupby('ParticipantId').MarkPercent.min()).reset_index() \
                                         .rename(columns={'MarkPercent': 'SelfDiagnosticMarkPercentMin'})
    temp['SelfDiagnosticMarkPercentMean'] = pd.DataFrame(selfdiagnosticresults[selfdiagnosticresults.SubjectId.isin(subjects_compliance[key])] \
                                                                      .groupby('ParticipantId').MarkPercent.mean()).reset_index() \
                                                                      .rename(columns={'MarkPercent': 'DiagnosticMarkPercentMean'})['DiagnosticMarkPercentMean']
    temp['SelfDiagnosticMarkPercentMax'] = pd.DataFrame(selfdiagnosticresults[selfdiagnosticresults.SubjectId.isin(subjects_compliance[key])] \
                                                                      .groupby('ParticipantId').MarkPercent.max()).reset_index() \
                                                                      .rename(columns={'MarkPercent': 'DiagnosticMarkPercentMax'})['DiagnosticMarkPercentMax']
    temp['SubjectId'] = key
    selfdiagnosticresults_processed = pd.concat([selfdiagnosticresults_processed,
                                                 temp])
    
data = pd.merge(data, selfdiagnosticresults_processed, on=['ParticipantId', 'SubjectId'], how='left')

# %%
selfdiagnosticresults_processed
# Out:
#                             ParticipantId  SelfDiagnosticMarkPercentMin  \
# 0    00294E7E-CA56-4437-97CD-EBB7A2C71CC9                          20.0
# 1    0030E228-8A5B-466C-BD89-6E0371B0737A                          66.0
# 2    009546E7-D14C-4803-B0E2-B20F7AA290FB                          86.0
# 3    0134A72D-D705-4F3D-8B97-AC5C111FEC77                          94.0
# 4    0293962C-87FE-4897-B6E0-9DF1D58CBD44                          22.0
# ..                                    ...                           ...
# 239  FBB2E944-9E48-46E7-8D25-BA73D708DCA8                          48.0
# 240  FC246649-576C-4568-A15C-0487645D7286                           0.0
# 241  FD9DA088-EA5E-49D4-8688-850A523FC36E                          72.0
# 242  FDE10D94-D175-4C5E-8AAD-D5EDF738E433                          88.0
# 243  FFD85683-D207-4F55-BD27-AD4C679BC116                           0.0
#
#      SelfDiagnosticMarkPercentMean  SelfDiagnosticMarkPercentMax  SubjectId
# 0                        20.000000                          20.0          4
# 1                        77.500000                          85.0          4
# 2                        86.000000                          86.0          4
# 3                        94.000000                          94.0          4
# 4                        61.400000                          94.0          4
# ..                             ...                           ...        ...
# 239                      48.000000                          48.0         86
# 240                      54.111111                          85.0         86
# 241                      72.000000                          72.0         86
# 242                      88.000000                          88.0         86
# 243                       5.666667                          17.0         86
#
# [5917 rows x 5 columns]

# %%
diagnosticresults_processed_all = pd.DataFrame(diagnosticresults.groupby('ParticipantId').MarkPercent.min()) \
                                     .reset_index().rename(columns={'MarkPercent':'AllDiagnosticMarkPercentMin'})
diagnosticresults_processed_all['AllDiagnosticMarkPercentMean'] = diagnosticresults.groupby('ParticipantId').MarkPercent.mean().values
diagnosticresults_processed_all['AllDiagnosticMarkPercentMax'] = diagnosticresults.groupby('ParticipantId').MarkPercent.max().values

data = pd.merge(data, diagnosticresults_processed_all, on=['ParticipantId'], how='left')

# %%
diagnosticresults_processed_all
# Out:
#                              ParticipantId  AllDiagnosticMarkPercentMin  \
# 0     00026864-3382-494F-96D7-D0A6BB717A42                         25.0
# 1     00051BBD-7F75-4D38-9BE1-E99E471DE10D                         50.0
# 2     00285945-82E0-4A66-A08E-61ABC661E876                         25.0
# 3     00329F1B-2C6A-4175-9A98-4E7D0FD716C0                         20.0
# 4     0036053E-423E-49FB-9E7B-CE4989102559                         35.0
# ...                                    ...                          ...
# 9678  FFD9B2E0-824E-4CD3-A202-8AA804973C13                         55.0
# 9679  FFDFD268-0BB4-4CA1-9574-99E7646ED421                         56.0
# 9680  FFE5E32A-8832-48D3-A05E-0A577D55AA96                         80.0
# 9681  FFECD224-842F-4F85-9D28-897A59DEAC88                         10.0
# 9682  FFF009C7-D82F-4347-B27D-7166885294ED                         25.0
#
#       AllDiagnosticMarkPercentMean  AllDiagnosticMarkPercentMax
# 0                             25.0                         25.0
# 1                             50.0                         50.0
# 2                             25.0                         25.0
# 3                             60.0                        100.0
# 4                             35.0                         35.0
# ...                            ...                          ...
# 9678                          55.0                         55.0
# 9679                          56.0                         56.0
# 9680                          80.0                         80.0
# 9681                          10.0                         10.0
# 9682                          25.0                         25.0
#
# [9683 rows x 4 columns]

# %%
selfdiagnosticresults_processed_all = pd.DataFrame(selfdiagnosticresults.groupby('ParticipantId').MarkPercent.min()) \
                                     .reset_index().rename(columns={'MarkPercent':'AllSelfDiagnosticMarkPercentMin'})
selfdiagnosticresults_processed_all['AllSelfDiagnosticMarkPercentMean'] = selfdiagnosticresults.groupby('ParticipantId').MarkPercent.mean().values
selfdiagnosticresults_processed_all['AllSelfDiagnosticMarkPercentMax'] = selfdiagnosticresults.groupby('ParticipantId').MarkPercent.max().values

data = pd.merge(data, selfdiagnosticresults_processed_all, on=['ParticipantId'], how='left')

# %%
selfdiagnosticresults_processed_all
# Out:
#                              ParticipantId  AllSelfDiagnosticMarkPercentMin  \
# 0     0004B810-D062-4E32-ACB5-0BCF3CBEF4F8                             85.0
# 1     00285945-82E0-4A66-A08E-61ABC661E876                             52.0
# 2     00294E7E-CA56-4437-97CD-EBB7A2C71CC9                             20.0
# 3     0030E228-8A5B-466C-BD89-6E0371B0737A                             50.0
# 4     0034E807-BDFB-445D-BE0B-EBCCD1065CAB                              5.0
# ...                                    ...                              ...
# 2592  FF94B56F-D0FA-4604-85C8-D83682D2FDEB                              0.0
# 2593  FFA2241E-5BD7-4019-BC18-96E84EDC989F                              6.0
# 2594  FFA51CD3-F551-44D5-B346-A2628B335532                              0.0
# 2595  FFC65D3F-1103-49AA-9E25-65003FDA47C6                             47.0
# 2596  FFD85683-D207-4F55-BD27-AD4C679BC116                              0.0
#
#       AllSelfDiagnosticMarkPercentMean  AllSelfDiagnosticMarkPercentMax
# 0                            93.933333                            102.0
# 1                            71.285714                             97.0
# 2                            30.666667                             38.0
# 3                            82.047619                            100.0
# 4                            13.000000                             21.0
# ...                                ...                              ...
# 2592                         44.600000                             85.0
# 2593                         22.000000                             38.0
# 2594                         16.611111                             53.0
# 2595                         47.000000                             47.0
# 2596                         27.318182                             94.0
#
# [2597 rows x 4 columns]

# %%
data.head()
# Out:
#                                      Id                         ParticipantId  \
# 0  000176B3-FD22-464F-80E4-1903332D8EFF  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
# 1  16B0AF81-E095-4646-A672-F8B2EFE824BE  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
# 2  E3763A42-0057-4281-92FD-CC6F5C0ED9A4  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
# 3  0007FBF5-CECE-4769-AAA4-F8D3B54460DE  4C5F3B22-6439-4255-83A3-9C2573607F96
# 4  89EDADB6-B6B8-42A4-9E02-2681F3D98B02  4C5F3B22-6439-4255-83A3-9C2573607F96
#
#      DateExam  MarkPercent  SubjectId  Parallel  \
# 0  2020-07-16           75         86        11
# 1  2020-07-06           79         75        11
# 2  2020-07-20           74          9        11
# 3  2020-07-20           77          9        11
# 4  2020-07-07           86         75        11
#
#                                  OOCode  DiagnosticMarkPercentMin  \
# 0  8D6D2905-A151-4B1B-AB98-F879C00CC736                       NaN
# 1  8D6D2905-A151-4B1B-AB98-F879C00CC736                       NaN
# 2  8D6D2905-A151-4B1B-AB98-F879C00CC736                       NaN
# 3  BFC27424-5AAD-465E-B169-A2474EBEE0C0                       NaN
# 4  BFC27424-5AAD-465E-B169-A2474EBEE0C0                       NaN
#
#    DiagnosticMarkPercentMean  DiagnosticMarkPercentMax  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#    SelfDiagnosticMarkPercentMin  SelfDiagnosticMarkPercentMean  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    SelfDiagnosticMarkPercentMax  AllDiagnosticMarkPercentMin  \
# 0                           NaN                         50.0
# 1                           NaN                         50.0
# 2                           NaN                         50.0
# 3                           NaN                         69.0
# 4                           NaN                         69.0
#
#    AllDiagnosticMarkPercentMean  AllDiagnosticMarkPercentMax  \
# 0                          50.0                         50.0
# 1                          50.0                         50.0
# 2                          50.0                         50.0
# 3                          69.0                         69.0
# 4                          69.0                         69.0
#
#    AllSelfDiagnosticMarkPercentMin  AllSelfDiagnosticMarkPercentMean  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    AllSelfDiagnosticMarkPercentMax
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
data['IsMedalist'] = 0
data.loc[data.ParticipantId.isin(medalistresults[medalistresults.Type == 1].ParticipantId.values), 'IsMedalist'] = 1

# %%
medalistsubjects = medalistsubjects.drop(['Id'], axis=1).rename(columns={'ResultId': 'Id'})

# %%
temp = pd.merge(medalistresults[medalistresults.Type == 0], medalistsubjects, on='Id', how='left')

# %%
temp.groupby('ParticipantId').Type.count().sort_values()
# Out:
# ParticipantId
# 023DAA87-A369-46B8-A811-7A372E6B2EA2    1
# 84F38A1F-EA78-42EC-AA2F-B285E35EB92F    1
# 85DA5046-7E51-450C-A6A8-81E39788CB17    1
# 88550A7C-B6DE-49A5-8E5B-775DAF741A36    1
# 89E1B511-5C56-4A4A-B10C-5DE163082AB0    1
#                                        ..
# 3E8F291A-8192-4389-B1E2-B1AF873E152F    1
# 3E497240-E2A3-4AFD-A104-6A75A0BA9A3F    1
# 4CD0552C-6071-42E5-8D27-1AC0935FD659    1
# 7753733E-1F7C-4411-AC03-2DDF5D9A5324    2
# E8B0231E-A8D2-4F0B-882B-7DB5EAFE9D76    3
# Name: Type, Length: 67, dtype: int64

# %%
temp[temp.ParticipantId == 'E8B0231E-A8D2-4F0B-882B-7DB5EAFE9D76']
# Out:
#      Id  Type                         ParticipantId  SubjectId
# 17  198     0  E8B0231E-A8D2-4F0B-882B-7DB5EAFE9D76         58
# 18  198     0  E8B0231E-A8D2-4F0B-882B-7DB5EAFE9D76         61
# 19  198     0  E8B0231E-A8D2-4F0B-882B-7DB5EAFE9D76         75

# %%
temp = temp[['ParticipantId', 'SubjectId']].copy()
temp['IsOlimpiad'] = 1

# %%
data = pd.merge(data, temp, on=['ParticipantId', 'SubjectId'], how='left')
data.loc[data.IsOlimpiad.isnull(), 'IsOlimpiad'] = 0
data.IsOlimpiad = data.IsOlimpiad.astype(int)

# %%
data.head(1)
# Out:
#                                      Id                         ParticipantId  \
# 0  000176B3-FD22-464F-80E4-1903332D8EFF  74A04FC2-A13B-468F-B4FF-08D4A3DDCEEA
#
#      DateExam  MarkPercent  SubjectId  Parallel  \
# 0  2020-07-16           75         86        11
#
#                                  OOCode  DiagnosticMarkPercentMin  \
# 0  8D6D2905-A151-4B1B-AB98-F879C00CC736                       NaN
#
#    DiagnosticMarkPercentMean  DiagnosticMarkPercentMax  ...  \
# 0                        NaN                       NaN  ...
#
#    SelfDiagnosticMarkPercentMean  SelfDiagnosticMarkPercentMax  \
# 0                            NaN                           NaN
#
#    AllDiagnosticMarkPercentMin  AllDiagnosticMarkPercentMean  \
# 0                         50.0                          50.0
#
#    AllDiagnosticMarkPercentMax  AllSelfDiagnosticMarkPercentMin  \
# 0                         50.0                              NaN
#
#    AllSelfDiagnosticMarkPercentMean  AllSelfDiagnosticMarkPercentMax  \
# 0                               NaN                              NaN
#
#    IsMedalist  IsOlimpiad
# 0           0           0
#
# [1 rows x 21 columns]

# %%
diagnosticresults_dynamic = pd.DataFrame(columns=['ParticipantId', 'SubjectId', 'DiagnosticMarkPercentDynamic'])

for idx in diagnosticresults[diagnosticresults.ParticipantId == '8C690BB7-4954-40C3-826B-C440D57C2C32'].ParticipantId.unique():
    for sub in diagnosticresults[diagnosticresults.ParticipantId == idx].SubjectId.unique():
        temp = diagnosticresults[(diagnosticresults.ParticipantId == idx)&(diagnosticresults.SubjectId == sub)] \
                                .set_index(['ParticipantId', 'SubjectId']).sort_values('TestDate')
        mark_changes = 0
        if len(temp.MarkPercent.values) < 2:
            pass
        else:
            marks = temp.MarkPercent.values
            for i in range(len(temp.MarkPercent.values)-1):
                mark_changes += marks[i+1] - marks[i]
            mark_changes /= len(marks)-1
        print(sub, mark_changes)
    break
# Out:
# 61 -16.0
# 12 -3.0
# 27 0
# 48 -8.0
# 86 11.0
# 77 -12.0
# 44 23.0
# 31 0
# 9 -6.5
# 75 18.0
# 32 0
# 11 0
# 4 -2.0

# %%
diagnosticresults[(diagnosticresults.ParticipantId == '8BFF3FC8-B66E-47BA-8964-9211C5C3B152')&
                  (diagnosticresults.SubjectId == 9)]
# Out:
#       ResultId  Source                         ParticipantId  StudentParallel  \
# 43      240121       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 103     240697       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 232     242977       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 352     244303       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 568     248824       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 763     253829       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 798     254492       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 897     258315       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 921     258597       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 1289    268762       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 1436    272064       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 1967    297426       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
# 1989    299743       0  8BFF3FC8-B66E-47BA-8964-9211C5C3B152               11
#
#                  TestDate  Mark  MaxMark  SubjectId  MarkPercent
# 43    2020-03-25 16:16:10  18.0     27.0          9         67.0
# 103   2020-03-27 18:05:48  15.0     27.0          9         56.0
# 232   2020-04-03 17:01:29  22.0     27.0          9         81.0
# 352   2020-04-06 15:47:43  18.0     27.0          9         67.0
# 568   2020-04-11 13:09:53  19.0     27.0          9         70.0
# 763   2020-04-15 12:07:24  16.0     27.0          9         59.0
# 798   2020-04-15 16:03:03  14.0     27.0          9         52.0
# 897   2020-04-17 17:02:06  20.0     27.0          9         74.0
# 921   2020-04-18 10:14:39  16.0     27.0          9         59.0
# 1289  2020-04-29 10:23:05  13.0     27.0          9         48.0
# 1436  2020-05-02 11:08:55  12.0     27.0          9         44.0
# 1967  2020-05-27 10:28:02  15.0     27.0          9         56.0
# 1989  2020-05-28 17:03:29  18.0     27.0          9         67.0

# %%
diagnosticresults.groupby('ParticipantId').SubjectId.count().sort_values()
# Out:
# ParticipantId
# 00026864-3382-494F-96D7-D0A6BB717A42     1
# A78D4404-774D-4E07-8D2C-690398053E91     1
# A78D5986-E251-4D21-BE6F-D1A661913971     1
# A7A1E7B5-1CE2-43CD-9077-20C51D2B7181     1
# A7A1F386-635F-4113-85EC-D5CAF7774B9F     1
#                                         ..
# 49A50A11-C34E-4771-9D3D-3CA92872D415    17
# 4DFEFA69-EB35-44BD-B239-6AA4DE66F866    18
# 8C690BB7-4954-40C3-826B-C440D57C2C32    26
# EBCE13AE-7518-4FE2-9E31-A49F9FBCA036    29
# 8BFF3FC8-B66E-47BA-8964-9211C5C3B152    37
# Name: SubjectId, Length: 9683, dtype: int64

# %%
subjects.iloc[74]
# Out:
# Id                75
# Name    Русский язык
# Name: 74, dtype: object

# %% [markdown]
# # Train model

# %%
train = data.drop(['Id', 'ParticipantId', 'DateExam', 'OOCode'], axis=1)

# %%
X = train.drop(['MarkPercent'], axis=1)
y = train['MarkPercent']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
model = CatBoostRegressor(eval_metric='RMSE', task_type='GPU')

# %%
model.fit(X_train, y_train, eval_set=(X_val, y_val),
          cat_features=['SubjectId', 'Parallel', 'IsMedalist', 'IsOlimpiad'], verbose=100)
# Out:
# Learning rate set to 0.084267
# 0:	learn: 22.6842492	test: 22.5606824	best: 22.5606824 (0)	total: 66.8ms	remaining: 1m 6s
# 100:	learn: 16.0242530	test: 16.2388772	best: 16.2388772 (100)	total: 3.43s	remaining: 30.5s
# 200:	learn: 15.6163012	test: 15.8616897	best: 15.8616820 (199)	total: 6.97s	remaining: 27.7s
# 300:	learn: 15.5424920	test: 15.8005537	best: 15.8005537 (300)	total: 10.3s	remaining: 23.9s
# 400:	learn: 15.5053617	test: 15.7806152	best: 15.7798128 (389)	total: 13.6s	remaining: 20.3s
# 500:	learn: 15.4806163	test: 15.7659092	best: 15.7659066 (499)	total: 16.9s	remaining: 16.8s
# 600:	learn: 15.4639126	test: 15.7587406	best: 15.7586779 (599)	total: 20s	remaining: 13.3s
# 700:	learn: 15.4496587	test: 15.7528140	best: 15.7525098 (637)	total: 23.4s	remaining: 9.97s
# 800:	learn: 15.4363943	test: 15.7472323	best: 15.7472323 (800)	total: 26.6s	remaining: 6.61s
# 900:	learn: 15.4281077	test: 15.7428416	best: 15.7428416 (900)	total: 29.7s	remaining: 3.26s
# 999:	learn: 15.4201987	test: 15.7417370	best: 15.7417205 (997)	total: 32.9s	remaining: 0us
# bestTest = 15.74172052
# bestIteration = 997
# Shrink model to first 998 iterations.

# %%
y.describe()
# Out:
# count    38600.000000
# mean        64.655233
# std         23.358458
# min          0.000000
# 25%         46.000000
# 50%         68.000000
# 75%         85.000000
# max        100.000000
# Name: MarkPercent, dtype: float64

# %% [markdown]
# # Questions
